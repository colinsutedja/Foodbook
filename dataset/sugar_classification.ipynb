# %%
# imports
import pandas as pd
import numpy as np

# %%
data1 = pd.read_csv('food_data_csv/FOOD-DATA-GROUP1.csv')
data2 = pd.read_csv('food_data_csv/FOOD-DATA-GROUP2.csv')
data3 = pd.read_csv('food_data_csv/FOOD-DATA-GROUP3.csv')
data4 = pd.read_csv('food_data_csv/FOOD-DATA-GROUP4.csv')
data5 = pd.read_csv('food_data_csv/FOOD-DATA-GROUP5.csv')
data1.shape, data2.shape, data3.shape, data4.shape, data5.shape
# Out:
# ((551, 37), (319, 37), (571, 37), (232, 37), (722, 37))

# %%
df = pd.concat([data1, data2, data3, data4, data5], ignore_index=True)
df
# Out:
#       Unnamed: 0.1  Unnamed: 0                              food  \
# 0                0           0                      cream cheese
# 1                1           1                 neufchatel cheese
# 2                2           2  requeijao cremoso light catupiry
# 3                3           3                    ricotta cheese
# 4                4           4              cream cheese low fat
# ...            ...         ...                               ...
# 2390           717         717                          jews ear
# 2391           718         718                   enoki mushrooms
# 2392           719         719                   morel mushrooms
# 2393           720         720          portabella mushrooms raw
# 2394           721         721                   oyster mushroom
#
#       Caloric Value     Fat  Saturated Fats  Monounsaturated Fats  \
# 0                51   5.000           2.900                 1.300
# 1               215  19.400          10.900                 4.900
# 2                49   3.600           2.300                 0.900
# 3                30   2.000           1.300                 0.500
# 4                30   2.300           1.400                 0.600
# ...             ...     ...             ...                   ...
# 2390             25   0.095           0.000                 0.000
# 2391              1   0.099           0.027                 0.000
# 2392              4   0.070           0.056                 0.031
# 2393             19   0.300           0.036                 0.016
# 2394              5   0.035           0.016                 0.039
#
#       Polyunsaturated Fats  Carbohydrates  Sugars  ...  Calcium  Copper  \
# 0                    0.200            0.8   0.500  ...    0.008  14.100
# 1                    0.800            3.1   2.700  ...   99.500   0.034
# 2                    0.000            0.9   3.400  ...    0.000   0.000
# 3                    0.002            1.5   0.091  ...    0.097  41.200
# 4                    0.042            1.2   0.900  ...   22.200   0.072
# ...                    ...            ...     ...  ...      ...     ...
# 2390                 0.000            6.7   0.000  ...   15.800   0.400
# 2391                 0.010            0.2   0.034  ...    0.000   0.000
# 2392                 0.007            0.7   0.096  ...    0.000   5.500
# 2393                 0.100            3.3   2.200  ...    2.600   0.200
# 2394                 0.099            0.9   0.200  ...    0.000   0.500
#
#        Iron  Magnesium  Manganese  Phosphorus  Potassium  Selenium   Zinc  \
# 0     0.082      0.027      1.300       0.091       15.5    19.100  0.039
# 1     0.100      8.500      0.088     117.300      129.2     0.054  0.700
# 2     0.000      0.000      0.000       0.000        0.0     0.000  0.000
# 3     0.097      0.096      4.000       0.024       30.8    43.800  0.035
# 4     0.008      1.200      0.098      22.800       37.1     0.034  0.053
# ...     ...        ...        ...         ...        ...       ...    ...
# 2390  0.600     24.800      0.040      13.900       42.6     0.034  0.700
# 2391  0.099      0.034      0.500       0.015        3.2    10.800  0.096
# 2392  0.056      1.600      2.500       0.060       25.0    53.000  0.069
# 2393  0.300      0.000      0.092      92.900      313.0     0.015  0.500
# 2394  0.008      0.200      2.700       0.055       18.0    63.000  0.048
#
#       Nutrition Density
# 0                 7.070
# 1               130.100
# 2                 5.400
# 3                 5.196
# 4                27.007
# ...                 ...
# 2390             24.249
# 2391              0.433
# 2392              1.727
# 2393              9.400
# 2394              1.804
#
# [2395 rows x 37 columns]

# %%
df['sugar per calorie'] = df['Sugars'] / df['Caloric Value']
df
# Out:
#       Unnamed: 0.1  Unnamed: 0                              food  \
# 0                0           0                      cream cheese
# 1                1           1                 neufchatel cheese
# 2                2           2  requeijao cremoso light catupiry
# 3                3           3                    ricotta cheese
# 4                4           4              cream cheese low fat
# ...            ...         ...                               ...
# 2390           717         717                          jews ear
# 2391           718         718                   enoki mushrooms
# 2392           719         719                   morel mushrooms
# 2393           720         720          portabella mushrooms raw
# 2394           721         721                   oyster mushroom
#
#       Caloric Value     Fat  Saturated Fats  Monounsaturated Fats  \
# 0                51   5.000           2.900                 1.300
# 1               215  19.400          10.900                 4.900
# 2                49   3.600           2.300                 0.900
# 3                30   2.000           1.300                 0.500
# 4                30   2.300           1.400                 0.600
# ...             ...     ...             ...                   ...
# 2390             25   0.095           0.000                 0.000
# 2391              1   0.099           0.027                 0.000
# 2392              4   0.070           0.056                 0.031
# 2393             19   0.300           0.036                 0.016
# 2394              5   0.035           0.016                 0.039
#
#       Polyunsaturated Fats  Carbohydrates  Sugars  ...  Copper   Iron  \
# 0                    0.200            0.8   0.500  ...  14.100  0.082
# 1                    0.800            3.1   2.700  ...   0.034  0.100
# 2                    0.000            0.9   3.400  ...   0.000  0.000
# 3                    0.002            1.5   0.091  ...  41.200  0.097
# 4                    0.042            1.2   0.900  ...   0.072  0.008
# ...                    ...            ...     ...  ...     ...    ...
# 2390                 0.000            6.7   0.000  ...   0.400  0.600
# 2391                 0.010            0.2   0.034  ...   0.000  0.099
# 2392                 0.007            0.7   0.096  ...   5.500  0.056
# 2393                 0.100            3.3   2.200  ...   0.200  0.300
# 2394                 0.099            0.9   0.200  ...   0.500  0.008
#
#       Magnesium  Manganese  Phosphorus  Potassium  Selenium   Zinc  \
# 0         0.027      1.300       0.091       15.5    19.100  0.039
# 1         8.500      0.088     117.300      129.2     0.054  0.700
# 2         0.000      0.000       0.000        0.0     0.000  0.000
# 3         0.096      4.000       0.024       30.8    43.800  0.035
# 4         1.200      0.098      22.800       37.1     0.034  0.053
# ...         ...        ...         ...        ...       ...    ...
# 2390     24.800      0.040      13.900       42.6     0.034  0.700
# 2391      0.034      0.500       0.015        3.2    10.800  0.096
# 2392      1.600      2.500       0.060       25.0    53.000  0.069
# 2393      0.000      0.092      92.900      313.0     0.015  0.500
# 2394      0.200      2.700       0.055       18.0    63.000  0.048
#
#       Nutrition Density  sugar per calorie
# 0                 7.070           0.009804
# 1               130.100           0.012558
# 2                 5.400           0.069388
# 3                 5.196           0.003033
# 4                27.007           0.030000
# ...                 ...                ...
# 2390             24.249           0.000000
# 2391              0.433           0.034000
# 2392              1.727           0.024000
# 2393              9.400           0.115789
# 2394              1.804           0.040000
#
# [2395 rows x 38 columns]

# %%
def sugar_level(value):
    if value > 0.025:
        return 'red'
    elif 0.015 <= value <= 0.025:
        return 'yellow'
    else:
        return 'green'

# %%
df['sugar health'] = df['sugar per calorie'].apply(sugar_level)
X = df[['food', 'Caloric Value', 'Sugars', 'sugar per calorie', 'sugar health']]
X
# Out:
#                                   food  Caloric Value  Sugars  \
# 0                         cream cheese             51   0.500
# 1                    neufchatel cheese            215   2.700
# 2     requeijao cremoso light catupiry             49   3.400
# 3                       ricotta cheese             30   0.091
# 4                 cream cheese low fat             30   0.900
# ...                                ...            ...     ...
# 2390                          jews ear             25   0.000
# 2391                   enoki mushrooms              1   0.034
# 2392                   morel mushrooms              4   0.096
# 2393          portabella mushrooms raw             19   2.200
# 2394                   oyster mushroom              5   0.200
#
#       sugar per calorie sugar health
# 0              0.009804        green
# 1              0.012558        green
# 2              0.069388          red
# 3              0.003033        green
# 4              0.030000          red
# ...                 ...          ...
# 2390           0.000000        green
# 2391           0.034000          red
# 2392           0.024000       yellow
# 2393           0.115789          red
# 2394           0.040000          red
#
# [2395 rows x 5 columns]

# %%
X['sugar health'].value_counts()
# Out:
# sugar health
# green     1578
# red        702
# yellow     115
# Name: count, dtype: int64

# %%
substring = 'bacon'

df[df['food'].str.contains(substring, case=False, na=False)]
# Out:
#       Unnamed: 0.1  Unnamed: 0                                  food  \
# 57              57          57  baked potato with cheese sauce bacon
# 62              62          62         biscuit with egg cheese bacon
# 119            119         119                biscuit with egg bacon
# 194            194         194         split pea soup with ham bacon
# 219            219         219                  bean with bacon soup
# 1146           276         276                      bacon beef steak
# 1148           278         278                                 bacon
# 1246           376         376              canadian style bacon raw
# 1271           401         401                   turkey bacon cooked
# 1338           468         468                         bacon roasted
# 1367           497         497                          bacon cooked
# 1370           500         500          canadian style bacon grilled
# 1373           503         503                           bacon baked
# 1698            25          25                          bacon grease
# 1972           299         299                 bacon tomato dressing
# 2050           377         377                        bacon meatless
# 2360           687         687           bacon ranch salad mcdonalds
#
#       Caloric Value   Fat  Saturated Fats  Monounsaturated Fats  \
# 57              451  25.9            10.1                   9.7
# 62              436  25.3             8.5                  11.7
# 119             458  31.1             8.0                  13.4
# 194             189   3.1             0.9                   1.2
# 219             106   2.1             1.0                   0.9
# 1146            146  12.5             4.5                   6.2
# 1148            106  10.2             0.0                   0.0
# 1246             45   2.0             0.6                   0.9
# 1271            313  22.9             6.8                   8.9
# 1338             43   3.3             1.1                   1.5
# 1367             43   3.1             1.1                   1.4
# 1370             43   2.0             0.7                   0.9
# 1373             44   3.5             1.1                   1.5
# 1698             39   4.3             1.7                   1.9
# 1972             49   5.3             0.8                   1.3
# 2050            446  42.5             6.7                  10.2
# 2360            389  20.1             5.2                   7.9
#
#       Polyunsaturated Fats  Carbohydrates  Sugars  ...   Iron  Magnesium  \
# 57                     4.8         44.400     0.0  ...  3.100       68.8
# 62                     2.8         35.400     2.5  ...  2.300       21.8
# 119                    7.5         28.600     3.3  ...  3.700       24.0
# 194                    0.6         28.600     0.0  ...  2.100        0.0
# 219                    0.2         16.400     0.6  ...  1.300       29.2
# 1146                   1.2          0.200     0.2  ...  0.500        4.8
# 1148                   0.0          0.200     0.2  ...  0.100        3.1
# 1246                   0.2          0.500     0.0  ...  0.200        4.8
# 1271                   5.6          2.500     0.0  ...  1.700       23.8
# 1338                   0.4          0.100     0.0  ...  0.096        0.1
# 1367                   0.5          0.068     0.0  ...  0.047        0.1
# 1370                   0.2          0.300     0.0  ...  0.200        4.9
# 1373                   0.4          0.100     0.0  ...  0.054        0.1
# 1698                   0.5          0.000     0.0  ...  0.000        0.0
# 1972                   2.9          0.300     0.3  ...  0.057        0.9
# 2050                  22.2          9.100     0.0  ...  3.500       27.4
# 2360                   5.2         19.400     4.9  ...  1.900        0.0
#
#       Manganese  Phosphorus  Potassium  Selenium   Zinc  Nutrition Density  \
# 57        0.500     346.800     1178.1     0.010  2.200            428.700
# 62        0.200     526.400      190.0     0.087  1.600            230.200
# 119       0.300     238.500      250.5     0.059  1.600            272.958
# 194       0.000       0.000        0.0     0.000  0.000             49.500
# 219       0.500      90.100      326.0     0.015  0.700             91.100
# 1146      0.064      40.200      109.0     0.020  0.900             25.400
# 1148      0.077      46.800      131.6     0.000  0.300             14.800
# 1246      0.006      69.300       98.0     0.082  0.400             10.900
# 1271      0.000     377.200      323.9     0.092  2.500             58.800
# 1338      2.600       0.003       42.6    45.200  0.090              6.516
# 1367      3.100       0.071       35.4    47.800  0.064              6.747
# 1370      0.023      69.600       91.7     0.058  0.400             10.600
# 1373      2.400       0.078       41.0    43.700  0.003              6.673
# 1698      0.000       0.000        0.0     0.000  0.031              4.300
# 1972      0.000       3.800       16.2     0.009  0.045              7.942
# 2050      0.300     100.800      244.8     0.004  0.600            107.300
# 2360      0.000       0.000        0.0     0.000  0.000            250.300
#
#       sugar per calorie  sugar health
# 57             0.000000         green
# 62             0.005734         green
# 119            0.007205         green
# 194            0.000000         green
# 219            0.005660         green
# 1146           0.001370         green
# 1148           0.001887         green
# 1246           0.000000         green
# 1271           0.000000         green
# 1338           0.000000         green
# 1367           0.000000         green
# 1370           0.000000         green
# 1373           0.000000         green
# 1698           0.000000         green
# 1972           0.006122         green
# 2050           0.000000         green
# 2360           0.012596         green
#
# [17 rows x 39 columns]

# %%
X = df.set_index('food')
X.get('sugar health').loc['egg fried']
# Out:
# 'green'

# %%
X.get('sugar health').loc['buttermilk pancakes']
# Out:
# 'green'
